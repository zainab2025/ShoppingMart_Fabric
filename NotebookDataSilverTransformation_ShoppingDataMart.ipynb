# %% [markdown]
# ## Siver Layer Notebook - Data Cleaning and integration</mark>

# %% [markdown]
# **### load Bronze Data**

# %%
from pyspark.sql.functions import *
df_customer = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Customers/ShoppingMart_customers.csv")
df_orders = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Orders/ShoppingMart_orders.csv")
df_products = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Products/ShoppingMart_products.csv")
# df_review = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Reviews/ShoppingMart_review.json")
# df_social_media = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Social_Media/ShoppingMart_social_media.json")
# df_web_logs = spark.read.format("csv").option("header","true").load("Files/ShoppingMart_Bronze_Web_Logs/ShoppingMart_web_logs.json")
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 3, Finished, Available, Finished, False)

# %%
df_orders = df_orders.dropna(subset=["orderID","OrderDate","CustomerID","ProductID","TotalAmount"])
df_orders = df_orders.withColumn("OrderDate",to_date(col("OrderDate")))
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 4, Finished, Available, Finished, False)

# %%
df_orders = df_orders.join(df_customer, on='CustomerID',how='inner').join(df_products, on='ProductID', how='inner')
display(df_orders)
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6a9293f5-2e6d-40a9-a4a3-565793e06715)

# %% [markdown]
# ### load structured Data into silverLayer

# %%
df_orders.write.mode("overwrite").parquet("Files/ShoppingMart_Silver_orders/ShoppingMart_customersOrders.csv")
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 6, Finished, Available, Finished, False)

# %% [markdown]
# **## load Unstructured Data**

# %%
df_review = spark.read.json("Files/ShoppingMart_Bronze_Reviews/ShoppingMart_review.json")
df_web_logs = spark.read.json("Files/ShoppingMart_Bronze_Web_Logs/ShoppingMart_web_logs.json")
display(df_web_logs)
df_social_media = spark.read.json("Files/ShoppingMart_Bronze_Social_Media/ShoppingMart_social_media.json")
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7e72b8ab-5701-41f7-92cd-e0b84f0a3f81)

# %%
df_review.write.mode("overwrite").parquet("Files/ShoppingMart_Silver_Reviews/ShoppingMart_review")
df_web_logs.write.mode("overwrite").parquet("Files/ShoppingMart_Silver_web_logs/ShoppingMart_web_logs")
df_social_media.write.mode("overwrite").parquet("Files/ShoppingMart_Silver_social_media/ShoppingMart_social_media")
# Out:
# StatementMeta(, 36cd6ee7-2316-48cc-bfc1-1a63722578f4, 13, Finished, Available, Finished, False)
